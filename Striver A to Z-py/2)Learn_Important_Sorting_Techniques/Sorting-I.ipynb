# %%
def SelectionSort(x):
    for i in range(0,len(nums)-1):
        mini = i
        for j in range(i+1,len(nums)):
            if nums[j]<nums[mini]:
                mini = j
        nums[mini],nums[i] = nums[i],nums[mini]
    return(nums)

# %%
def BubbleSort(x):
    for i in range(len(nums)-1,-1,-1):
        swaps = 0
        for j in range(i):
            if nums[j]>nums[j+1]:
                nums[j],nums[j+1] = nums[j+1],nums[j]
                swaps += 1
        if swaps == 0:
            break
    return(nums)

# %%
def InsertionSort(x):
    for i in range(len(nums)):
        j = i
        while(j>0):
            if nums[j]<nums[j-1]:
                nums[j],nums[j-1]=nums[j-1],nums[j]
            j -= 1
    return(nums)

# %%
nums = [1,2,1,1,4,3]
print("SelectionSort:",SelectionSort(nums))
print("BubbleSort:",BubbleSort(nums))
print("InsertionSort:",InsertionSort(nums))
# Out:
# SelectionSort: [1, 1, 1, 2, 3, 4]
# BubbleSort: [1, 1, 1, 2, 3, 4]
# InsertionSort: [1, 1, 1, 2, 3, 4]
