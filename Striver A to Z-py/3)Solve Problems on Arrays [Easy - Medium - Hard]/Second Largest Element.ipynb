# %%
class Solution:
    def secondLargestElement(self, nums):
        nums.sort()
        largest = nums[len(nums)-1]
        seclargest = -1
        for i in range(len(nums)-1,-1,-1):
            if nums[i]<largest:
                seclargest = nums[i]
                break
        return seclargest
