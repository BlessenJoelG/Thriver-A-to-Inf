# %%
#TimeComplexities

# %%
#O(n)~Linear "n" times
n,c = int(input()),0
for i in range(n):
    c += 1
print(c)

# %%
#O(n**2)~Nested "n*n" times
for i in range(5):
    for j in range(5):
        print("hello")
